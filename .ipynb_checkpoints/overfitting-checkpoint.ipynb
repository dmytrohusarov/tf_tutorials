# %%
import tensorflow as tf
from tensorflow import keras

import numpy as np
import matplotlib.pyplot as plt

print(tf.__version__)
# Out:
# 1.10.0

# %%
NUM_WORDS = 10000

(train_data, train_labels), (test_data, test_labels) = keras.datasets.imdb.load_data(num_words=NUM_WORDS)

def multi_hot_sequences(sequences, dimension):
    # Create an all-zero matrix of shape (len(sequences), dimension)
    results = np.zeros((len(sequences), dimension))
    for i, word_indices in enumerate(sequences):
        results[i, word_indices] = 1.0  # set specific indices of results[i] to 1s
    return results


train_data = multi_hot_sequences(train_data, dimension=NUM_WORDS)
test_data = multi_hot_sequences(test_data, dimension=NUM_WORDS)

# %%
plt.plot(train_data[0])

# %%
baseline_model = keras.Sequential([
    # `input_shape` is only required here so that `.summary` works. 
    keras.layers.Dense(16, activation=tf.nn.relu, input_shape=(NUM_WORDS,)),
    keras.layers.Dense(16, activation=tf.nn.relu),
    keras.layers.Dense(1, activation=tf.nn.sigmoid)
])

baseline_model.compile(optimizer='adam',
                       loss='binary_crossentropy',
                       metrics=['accuracy', 'binary_crossentropy'])

baseline_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 16)                160016
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                272
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 160,305
# Trainable params: 160,305
# Non-trainable params: 0
# _________________________________________________________________

# %%
baseline_history = baseline_model.fit(train_data,
                                      train_labels,
                                      epochs=20,
                                      batch_size=512,
                                      validation_data=(test_data, test_labels),
                                      verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
#  - 3s - loss: 0.4803 - acc: 0.8112 - binary_crossentropy: 0.4803 - val_loss: 0.3367 - val_acc: 0.8766 - val_binary_crossentropy: 0.3367
# Epoch 2/20
#  - 2s - loss: 0.2497 - acc: 0.9136 - binary_crossentropy: 0.2497 - val_loss: 0.2846 - val_acc: 0.8884 - val_binary_crossentropy: 0.2846
# Epoch 3/20
#  - 2s - loss: 0.1856 - acc: 0.9364 - binary_crossentropy: 0.1856 - val_loss: 0.2861 - val_acc: 0.8863 - val_binary_crossentropy: 0.2861
# Epoch 4/20
#  - 2s - loss: 0.1499 - acc: 0.9498 - binary_crossentropy: 0.1499 - val_loss: 0.3056 - val_acc: 0.8802 - val_binary_crossentropy: 0.3056
# Epoch 5/20
#  - 2s - loss: 0.1232 - acc: 0.9602 - binary_crossentropy: 0.1232 - val_loss: 0.3292 - val_acc: 0.8753 - val_binary_crossentropy: 0.3292
# Epoch 6/20
#  - 2s - loss: 0.1006 - acc: 0.9699 - binary_crossentropy: 0.1006 - val_loss: 0.3552 - val_acc: 0.8718 - val_binary_crossentropy: 0.3552
# Epoch 7/20
#  - 2s - loss: 0.0810 - acc: 0.9774 - binary_crossentropy: 0.0810 - val_loss: 0.3976 - val_acc: 0.8643 - val_binary_crossentropy: 0.3976
# Epoch 8/20
#  - 2s - loss: 0.0651 - acc: 0.9836 - binary_crossentropy: 0.0651 - val_loss: 0.4209 - val_acc: 0.8651 - val_binary_crossentropy: 0.4209
# Epoch 9/20
#  - 2s - loss: 0.0509 - acc: 0.9886 - binary_crossentropy: 0.0509 - val_loss: 0.4564 - val_acc: 0.8629 - val_binary_crossentropy: 0.4564
# Epoch 10/20
#  - 2s - loss: 0.0383 - acc: 0.9933 - binary_crossentropy: 0.0383 - val_loss: 0.4942 - val_acc: 0.8597 - val_binary_crossentropy: 0.4942
# Epoch 11/20
#  - 2s - loss: 0.0292 - acc: 0.9962 - binary_crossentropy: 0.0292 - val_loss: 0.5272 - val_acc: 0.8588 - val_binary_crossentropy: 0.5272
# Epoch 12/20
#  - 2s - loss: 0.0222 - acc: 0.9976 - binary_crossentropy: 0.0222 - val_loss: 0.5644 - val_acc: 0.8561 - val_binary_crossentropy: 0.5644
# Epoch 13/20
#  - 3s - loss: 0.0166 - acc: 0.9984 - binary_crossentropy: 0.0166 - val_loss: 0.5918 - val_acc: 0.8563 - val_binary_crossentropy: 0.5918
# Epoch 14/20
#  - 3s - loss: 0.0126 - acc: 0.9992 - binary_crossentropy: 0.0126 - val_loss: 0.6234 - val_acc: 0.8551 - val_binary_crossentropy: 0.6234
# Epoch 15/20
#  - 2s - loss: 0.0094 - acc: 0.9996 - binary_crossentropy: 0.0094 - val_loss: 0.6487 - val_acc: 0.8562 - val_binary_crossentropy: 0.6487
# Epoch 16/20
#  - 2s - loss: 0.0074 - acc: 0.9998 - binary_crossentropy: 0.0074 - val_loss: 0.6748 - val_acc: 0.8555 - val_binary_crossentropy: 0.6748
# Epoch 17/20
#  - 2s - loss: 0.0058 - acc: 0.9999 - binary_crossentropy: 0.0058 - val_loss: 0.6983 - val_acc: 0.8565 - val_binary_crossentropy: 0.6983
# Epoch 18/20
#  - 2s - loss: 0.0048 - acc: 1.0000 - binary_crossentropy: 0.0048 - val_loss: 0.7221 - val_acc: 0.8552 - val_binary_crossentropy: 0.7221
# Epoch 19/20
#  - 2s - loss: 0.0040 - acc: 1.0000 - binary_crossentropy: 0.0040 - val_loss: 0.7377 - val_acc: 0.8556 - val_binary_crossentropy: 0.7377
# Epoch 20/20
#  - 2s - loss: 0.0033 - acc: 1.0000 - binary_crossentropy: 0.0033 - val_loss: 0.7598 - val_acc: 0.8545 - val_binary_crossentropy: 0.7598

# %%
smaller_model = keras.Sequential([
    keras.layers.Dense(4, activation=tf.nn.relu, input_shape=(NUM_WORDS,)),
    keras.layers.Dense(4, activation=tf.nn.relu),
    keras.layers.Dense(1, activation=tf.nn.sigmoid)
])

smaller_model.compile(optimizer='adam',
                loss='binary_crossentropy',
                metrics=['accuracy', 'binary_crossentropy'])

smaller_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 4)                 40004
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 20
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 5
# =================================================================
# Total params: 40,029
# Trainable params: 40,029
# Non-trainable params: 0
# _________________________________________________________________

# %%
smaller_history = smaller_model.fit(train_data,
                                    train_labels,
                                    epochs=20,
                                    batch_size=512,
                                    validation_data=(test_data, test_labels),
                                    verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
#  - 2s - loss: 0.6324 - acc: 0.7516 - binary_crossentropy: 0.6324 - val_loss: 0.5626 - val_acc: 0.8334 - val_binary_crossentropy: 0.5626
# Epoch 2/20
#  - 2s - loss: 0.4732 - acc: 0.8648 - binary_crossentropy: 0.4732 - val_loss: 0.4251 - val_acc: 0.8608 - val_binary_crossentropy: 0.4251
# Epoch 3/20
#  - 2s - loss: 0.3470 - acc: 0.8932 - binary_crossentropy: 0.3470 - val_loss: 0.3444 - val_acc: 0.8786 - val_binary_crossentropy: 0.3444
# Epoch 4/20
#  - 2s - loss: 0.2727 - acc: 0.9108 - binary_crossentropy: 0.2727 - val_loss: 0.3064 - val_acc: 0.8849 - val_binary_crossentropy: 0.3064
# Epoch 5/20
#  - 2s - loss: 0.2286 - acc: 0.9234 - binary_crossentropy: 0.2286 - val_loss: 0.2902 - val_acc: 0.8880 - val_binary_crossentropy: 0.2902
# Epoch 6/20
#  - 2s - loss: 0.1987 - acc: 0.9337 - binary_crossentropy: 0.1987 - val_loss: 0.2827 - val_acc: 0.8892 - val_binary_crossentropy: 0.2827
# Epoch 7/20
#  - 2s - loss: 0.1766 - acc: 0.9422 - binary_crossentropy: 0.1766 - val_loss: 0.2825 - val_acc: 0.8882 - val_binary_crossentropy: 0.2825
# Epoch 8/20
#  - 2s - loss: 0.1590 - acc: 0.9471 - binary_crossentropy: 0.1590 - val_loss: 0.2862 - val_acc: 0.8869 - val_binary_crossentropy: 0.2862
# Epoch 9/20
#  - 2s - loss: 0.1454 - acc: 0.9524 - binary_crossentropy: 0.1454 - val_loss: 0.2925 - val_acc: 0.8862 - val_binary_crossentropy: 0.2925
# Epoch 10/20
#  - 2s - loss: 0.1323 - acc: 0.9578 - binary_crossentropy: 0.1323 - val_loss: 0.3036 - val_acc: 0.8812 - val_binary_crossentropy: 0.3036
# Epoch 11/20
#  - 2s - loss: 0.1216 - acc: 0.9620 - binary_crossentropy: 0.1216 - val_loss: 0.3114 - val_acc: 0.8810 - val_binary_crossentropy: 0.3114
# Epoch 12/20
#  - 2s - loss: 0.1118 - acc: 0.9660 - binary_crossentropy: 0.1118 - val_loss: 0.3258 - val_acc: 0.8775 - val_binary_crossentropy: 0.3258
# Epoch 13/20
#  - 2s - loss: 0.1029 - acc: 0.9692 - binary_crossentropy: 0.1029 - val_loss: 0.3343 - val_acc: 0.8778 - val_binary_crossentropy: 0.3343
# Epoch 14/20
#  - 2s - loss: 0.0954 - acc: 0.9724 - binary_crossentropy: 0.0954 - val_loss: 0.3476 - val_acc: 0.8748 - val_binary_crossentropy: 0.3476
# Epoch 15/20
#  - 2s - loss: 0.0877 - acc: 0.9755 - binary_crossentropy: 0.0877 - val_loss: 0.3611 - val_acc: 0.8738 - val_binary_crossentropy: 0.3611
# Epoch 16/20
#  - 2s - loss: 0.0809 - acc: 0.9784 - binary_crossentropy: 0.0809 - val_loss: 0.3759 - val_acc: 0.8724 - val_binary_crossentropy: 0.3759
# Epoch 17/20
#  - 2s - loss: 0.0748 - acc: 0.9813 - binary_crossentropy: 0.0748 - val_loss: 0.3910 - val_acc: 0.8700 - val_binary_crossentropy: 0.3910
# Epoch 18/20
#  - 2s - loss: 0.0688 - acc: 0.9834 - binary_crossentropy: 0.0688 - val_loss: 0.4082 - val_acc: 0.8676 - val_binary_crossentropy: 0.4082
# Epoch 19/20
#  - 2s - loss: 0.0634 - acc: 0.9855 - binary_crossentropy: 0.0634 - val_loss: 0.4227 - val_acc: 0.8671 - val_binary_crossentropy: 0.4227
# Epoch 20/20
#  - 2s - loss: 0.0580 - acc: 0.9875 - binary_crossentropy: 0.0580 - val_loss: 0.4403 - val_acc: 0.8662 - val_binary_crossentropy: 0.4403

# %%
bigger_model = keras.models.Sequential([
    keras.layers.Dense(512, activation=tf.nn.relu, input_shape=(NUM_WORDS,)),
    keras.layers.Dense(512, activation=tf.nn.relu),
    keras.layers.Dense(1, activation=tf.nn.sigmoid)
])

bigger_model.compile(optimizer='adam',
                     loss='binary_crossentropy',
                     metrics=['accuracy','binary_crossentropy'])

bigger_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 512)               5120512
# _________________________________________________________________
# dense_7 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 5,383,681
# Trainable params: 5,383,681
# Non-trainable params: 0
# _________________________________________________________________

# %%
bigger_history = bigger_model.fit(train_data, train_labels,
                                  epochs=20,
                                  batch_size=512,
                                  validation_data=(test_data, test_labels),
                                  verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
#  - 9s - loss: 0.3527 - acc: 0.8473 - binary_crossentropy: 0.3527 - val_loss: 0.3026 - val_acc: 0.8770 - val_binary_crossentropy: 0.3026
# Epoch 2/20
#  - 8s - loss: 0.1388 - acc: 0.9493 - binary_crossentropy: 0.1388 - val_loss: 0.3624 - val_acc: 0.8632 - val_binary_crossentropy: 0.3624
# Epoch 3/20
#  - 8s - loss: 0.0432 - acc: 0.9883 - binary_crossentropy: 0.0432 - val_loss: 0.4283 - val_acc: 0.8700 - val_binary_crossentropy: 0.4283
# Epoch 4/20
#  - 8s - loss: 0.0062 - acc: 0.9994 - binary_crossentropy: 0.0062 - val_loss: 0.5919 - val_acc: 0.8692 - val_binary_crossentropy: 0.5919
# Epoch 5/20
#  - 8s - loss: 6.8468e-04 - acc: 1.0000 - binary_crossentropy: 6.8468e-04 - val_loss: 0.6739 - val_acc: 0.8708 - val_binary_crossentropy: 0.6739
# Epoch 6/20
#  - 8s - loss: 2.1914e-04 - acc: 1.0000 - binary_crossentropy: 2.1914e-04 - val_loss: 0.7097 - val_acc: 0.8714 - val_binary_crossentropy: 0.7097
# Epoch 7/20
#  - 8s - loss: 1.3848e-04 - acc: 1.0000 - binary_crossentropy: 1.3848e-04 - val_loss: 0.7344 - val_acc: 0.8712 - val_binary_crossentropy: 0.7344
# Epoch 8/20
#  - 8s - loss: 1.0003e-04 - acc: 1.0000 - binary_crossentropy: 1.0003e-04 - val_loss: 0.7534 - val_acc: 0.8712 - val_binary_crossentropy: 0.7534
# Epoch 9/20
#  - 9s - loss: 7.6955e-05 - acc: 1.0000 - binary_crossentropy: 7.6955e-05 - val_loss: 0.7691 - val_acc: 0.8714 - val_binary_crossentropy: 0.7691
# Epoch 10/20
#  - 8s - loss: 6.1373e-05 - acc: 1.0000 - binary_crossentropy: 6.1373e-05 - val_loss: 0.7818 - val_acc: 0.8712 - val_binary_crossentropy: 0.7818
# Epoch 11/20
#  - 8s - loss: 5.0199e-05 - acc: 1.0000 - binary_crossentropy: 5.0199e-05 - val_loss: 0.7937 - val_acc: 0.8713 - val_binary_crossentropy: 0.7937
# Epoch 12/20
#  - 8s - loss: 4.1800e-05 - acc: 1.0000 - binary_crossentropy: 4.1800e-05 - val_loss: 0.8039 - val_acc: 0.8713 - val_binary_crossentropy: 0.8039
# Epoch 13/20
#  - 8s - loss: 3.5377e-05 - acc: 1.0000 - binary_crossentropy: 3.5377e-05 - val_loss: 0.8131 - val_acc: 0.8712 - val_binary_crossentropy: 0.8131
# Epoch 14/20
#  - 8s - loss: 3.0359e-05 - acc: 1.0000 - binary_crossentropy: 3.0359e-05 - val_loss: 0.8219 - val_acc: 0.8713 - val_binary_crossentropy: 0.8219
# Epoch 15/20
#  - 9s - loss: 2.6273e-05 - acc: 1.0000 - binary_crossentropy: 2.6273e-05 - val_loss: 0.8300 - val_acc: 0.8713 - val_binary_crossentropy: 0.8300
# Epoch 16/20
#  - 9s - loss: 2.2969e-05 - acc: 1.0000 - binary_crossentropy: 2.2969e-05 - val_loss: 0.8369 - val_acc: 0.8712 - val_binary_crossentropy: 0.8369
# Epoch 17/20
#  - 8s - loss: 2.0233e-05 - acc: 1.0000 - binary_crossentropy: 2.0233e-05 - val_loss: 0.8445 - val_acc: 0.8714 - val_binary_crossentropy: 0.8445
# Epoch 18/20
#  - 8s - loss: 1.7967e-05 - acc: 1.0000 - binary_crossentropy: 1.7967e-05 - val_loss: 0.8504 - val_acc: 0.8713 - val_binary_crossentropy: 0.8504
# Epoch 19/20
#  - 8s - loss: 1.6013e-05 - acc: 1.0000 - binary_crossentropy: 1.6013e-05 - val_loss: 0.8565 - val_acc: 0.8712 - val_binary_crossentropy: 0.8565
# Epoch 20/20
#  - 8s - loss: 1.4375e-05 - acc: 1.0000 - binary_crossentropy: 1.4375e-05 - val_loss: 0.8626 - val_acc: 0.8711 - val_binary_crossentropy: 0.8626

# %%
def plot_history(histories, key='binary_crossentropy'):
  plt.figure(figsize=(16,10))
    
  for name, history in histories:
    val = plt.plot(history.epoch, history.history['val_'+key],
                   '--', label=name.title()+' Val')
    plt.plot(history.epoch, history.history[key], color=val[0].get_color(),
             label=name.title()+' Train')

  plt.xlabel('Epochs')
  plt.ylabel(key.replace('_',' ').title())
  plt.legend()

  plt.xlim([0,max(history.epoch)])


plot_history([('baseline', baseline_history),
              ('smaller', smaller_history),
              ('bigger', bigger_history)])

# %%
l2_model = keras.models.Sequential([
    keras.layers.Dense(16, kernel_regularizer=keras.regularizers.l2(0.001),
                       activation=tf.nn.relu, input_shape=(NUM_WORDS,)),
    keras.layers.Dense(16, kernel_regularizer=keras.regularizers.l2(0.001),
                       activation=tf.nn.relu),
    keras.layers.Dense(1, activation=tf.nn.sigmoid)
])

l2_model.compile(optimizer='adam',
                 loss='binary_crossentropy',
                 metrics=['accuracy', 'binary_crossentropy'])

l2_model_history = l2_model.fit(train_data, train_labels,
                                epochs=20,
                                batch_size=512,
                                validation_data=(test_data, test_labels),
                                verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
#  - 3s - loss: 0.5437 - acc: 0.7972 - binary_crossentropy: 0.5063 - val_loss: 0.3990 - val_acc: 0.8740 - val_binary_crossentropy: 0.3582
# Epoch 2/20
#  - 2s - loss: 0.3208 - acc: 0.9042 - binary_crossentropy: 0.2741 - val_loss: 0.3392 - val_acc: 0.8870 - val_binary_crossentropy: 0.2882
# Epoch 3/20
#  - 2s - loss: 0.2676 - acc: 0.9239 - binary_crossentropy: 0.2139 - val_loss: 0.3380 - val_acc: 0.8868 - val_binary_crossentropy: 0.2823
# Epoch 4/20
#  - 2s - loss: 0.2424 - acc: 0.9358 - binary_crossentropy: 0.1851 - val_loss: 0.3468 - val_acc: 0.8839 - val_binary_crossentropy: 0.2885
# Epoch 5/20
#  - 2s - loss: 0.2292 - acc: 0.9415 - binary_crossentropy: 0.1692 - val_loss: 0.3586 - val_acc: 0.8811 - val_binary_crossentropy: 0.2978
# Epoch 6/20
#  - 2s - loss: 0.2164 - acc: 0.9472 - binary_crossentropy: 0.1551 - val_loss: 0.3708 - val_acc: 0.8780 - val_binary_crossentropy: 0.3092
# Epoch 7/20
#  - 2s - loss: 0.2097 - acc: 0.9496 - binary_crossentropy: 0.1470 - val_loss: 0.3845 - val_acc: 0.8750 - val_binary_crossentropy: 0.3212
# Epoch 8/20
#  - 3s - loss: 0.2015 - acc: 0.9534 - binary_crossentropy: 0.1375 - val_loss: 0.3921 - val_acc: 0.8730 - val_binary_crossentropy: 0.3280
# Epoch 9/20
#  - 2s - loss: 0.1961 - acc: 0.9550 - binary_crossentropy: 0.1316 - val_loss: 0.4064 - val_acc: 0.8706 - val_binary_crossentropy: 0.3414
# Epoch 10/20
#  - 3s - loss: 0.1945 - acc: 0.9556 - binary_crossentropy: 0.1289 - val_loss: 0.4232 - val_acc: 0.8676 - val_binary_crossentropy: 0.3572
# Epoch 11/20
#  - 2s - loss: 0.1897 - acc: 0.9579 - binary_crossentropy: 0.1232 - val_loss: 0.4282 - val_acc: 0.8674 - val_binary_crossentropy: 0.3612
# Epoch 12/20
#  - 2s - loss: 0.1857 - acc: 0.9588 - binary_crossentropy: 0.1187 - val_loss: 0.4474 - val_acc: 0.8637 - val_binary_crossentropy: 0.3801
# Epoch 13/20
#  - 2s - loss: 0.1857 - acc: 0.9585 - binary_crossentropy: 0.1175 - val_loss: 0.4490 - val_acc: 0.8649 - val_binary_crossentropy: 0.3806
# Epoch 14/20
#  - 2s - loss: 0.1763 - acc: 0.9638 - binary_crossentropy: 0.1080 - val_loss: 0.4560 - val_acc: 0.8620 - val_binary_crossentropy: 0.3881
# Epoch 15/20
#  - 3s - loss: 0.1711 - acc: 0.9652 - binary_crossentropy: 0.1032 - val_loss: 0.4673 - val_acc: 0.8625 - val_binary_crossentropy: 0.3993
# Epoch 16/20
#  - 2s - loss: 0.1684 - acc: 0.9670 - binary_crossentropy: 0.1002 - val_loss: 0.4776 - val_acc: 0.8602 - val_binary_crossentropy: 0.4092
# Epoch 17/20
#  - 2s - loss: 0.1671 - acc: 0.9666 - binary_crossentropy: 0.0987 - val_loss: 0.4854 - val_acc: 0.8601 - val_binary_crossentropy: 0.4165
# Epoch 18/20
#  - 2s - loss: 0.1653 - acc: 0.9666 - binary_crossentropy: 0.0961 - val_loss: 0.5023 - val_acc: 0.8574 - val_binary_crossentropy: 0.4326
# Epoch 19/20
#  - 2s - loss: 0.1633 - acc: 0.9674 - binary_crossentropy: 0.0935 - val_loss: 0.5057 - val_acc: 0.8599 - val_binary_crossentropy: 0.4357
# Epoch 20/20
#  - 2s - loss: 0.1601 - acc: 0.9696 - binary_crossentropy: 0.0897 - val_loss: 0.5169 - val_acc: 0.8568 - val_binary_crossentropy: 0.4463

# %%
plot_history([('baseline', baseline_history),
              ('l2', l2_model_history)])

# %%
dpt_model = keras.models.Sequential([
    keras.layers.Dense(16, activation=tf.nn.relu, input_shape=(NUM_WORDS,)),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(16, activation=tf.nn.relu),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(1, activation=tf.nn.sigmoid)
])

dpt_model.compile(optimizer='adam',
                  loss='binary_crossentropy',
                  metrics=['accuracy','binary_crossentropy'])

dpt_model_history = dpt_model.fit(train_data, train_labels,
                                  epochs=20,
                                  batch_size=512,
                                  validation_data=(test_data, test_labels),
                                  verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
#  - 3s - loss: 0.6423 - acc: 0.6188 - binary_crossentropy: 0.6423 - val_loss: 0.5172 - val_acc: 0.8350 - val_binary_crossentropy: 0.5172
# Epoch 2/20
#  - 2s - loss: 0.4986 - acc: 0.7826 - binary_crossentropy: 0.4986 - val_loss: 0.3798 - val_acc: 0.8768 - val_binary_crossentropy: 0.3798
# Epoch 3/20
#  - 2s - loss: 0.3904 - acc: 0.8589 - binary_crossentropy: 0.3904 - val_loss: 0.3195 - val_acc: 0.8848 - val_binary_crossentropy: 0.3195
# Epoch 4/20
#  - 2s - loss: 0.3247 - acc: 0.8923 - binary_crossentropy: 0.3247 - val_loss: 0.2913 - val_acc: 0.8824 - val_binary_crossentropy: 0.2913
# Epoch 5/20
#  - 2s - loss: 0.2739 - acc: 0.9124 - binary_crossentropy: 0.2739 - val_loss: 0.2864 - val_acc: 0.8866 - val_binary_crossentropy: 0.2864
# Epoch 6/20
#  - 2s - loss: 0.2341 - acc: 0.9256 - binary_crossentropy: 0.2341 - val_loss: 0.2911 - val_acc: 0.8839 - val_binary_crossentropy: 0.2911
# Epoch 7/20
#  - 2s - loss: 0.2104 - acc: 0.9318 - binary_crossentropy: 0.2104 - val_loss: 0.3068 - val_acc: 0.8796 - val_binary_crossentropy: 0.3068
# Epoch 8/20
#  - 2s - loss: 0.1862 - acc: 0.9408 - binary_crossentropy: 0.1862 - val_loss: 0.3223 - val_acc: 0.8811 - val_binary_crossentropy: 0.3223
# Epoch 9/20
#  - 2s - loss: 0.1670 - acc: 0.9468 - binary_crossentropy: 0.1670 - val_loss: 0.3432 - val_acc: 0.8786 - val_binary_crossentropy: 0.3432
# Epoch 10/20
#  - 2s - loss: 0.1480 - acc: 0.9524 - binary_crossentropy: 0.1480 - val_loss: 0.3598 - val_acc: 0.8790 - val_binary_crossentropy: 0.3598
# Epoch 11/20
#  - 2s - loss: 0.1381 - acc: 0.9580 - binary_crossentropy: 0.1381 - val_loss: 0.3786 - val_acc: 0.8782 - val_binary_crossentropy: 0.3786
# Epoch 12/20
#  - 2s - loss: 0.1277 - acc: 0.9612 - binary_crossentropy: 0.1277 - val_loss: 0.4044 - val_acc: 0.8770 - val_binary_crossentropy: 0.4044
# Epoch 13/20
#  - 2s - loss: 0.1192 - acc: 0.9631 - binary_crossentropy: 0.1192 - val_loss: 0.4052 - val_acc: 0.8726 - val_binary_crossentropy: 0.4052
# Epoch 14/20
#  - 2s - loss: 0.1098 - acc: 0.9668 - binary_crossentropy: 0.1098 - val_loss: 0.4530 - val_acc: 0.8764 - val_binary_crossentropy: 0.4530
# Epoch 15/20
#  - 2s - loss: 0.1025 - acc: 0.9686 - binary_crossentropy: 0.1025 - val_loss: 0.4467 - val_acc: 0.8739 - val_binary_crossentropy: 0.4467
# Epoch 16/20
#  - 2s - loss: 0.1022 - acc: 0.9682 - binary_crossentropy: 0.1022 - val_loss: 0.4698 - val_acc: 0.8728 - val_binary_crossentropy: 0.4698
# Epoch 17/20
#  - 2s - loss: 0.0975 - acc: 0.9699 - binary_crossentropy: 0.0975 - val_loss: 0.4830 - val_acc: 0.8744 - val_binary_crossentropy: 0.4830
# Epoch 18/20
#  - 2s - loss: 0.0885 - acc: 0.9732 - binary_crossentropy: 0.0885 - val_loss: 0.5118 - val_acc: 0.8752 - val_binary_crossentropy: 0.5118
# Epoch 19/20
#  - 2s - loss: 0.0830 - acc: 0.9743 - binary_crossentropy: 0.0830 - val_loss: 0.5300 - val_acc: 0.8750 - val_binary_crossentropy: 0.5300
# Epoch 20/20
#  - 2s - loss: 0.0823 - acc: 0.9746 - binary_crossentropy: 0.0823 - val_loss: 0.5658 - val_acc: 0.8748 - val_binary_crossentropy: 0.5658

# %%
plot_history([('baseline', baseline_history),
              ('dropout', dpt_model_history)])
